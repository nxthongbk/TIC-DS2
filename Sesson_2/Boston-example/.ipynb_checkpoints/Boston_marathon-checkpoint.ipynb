# %%
# import neccessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# show plot intermediately under the calling cell
# %matplotlib inline

# disable some warnings
import warnings
warnings.simplefilter(action = "ignore")

# set to unlimited column display:
pd.set_option('display.max_columns', None)

# import database
df = pd.read_csv('results-2014.csv')

# %% [markdown]
# <center>Table: (sample) Dataframe including column dtype</center>

# %%
dtypes = pd.Series(df.dtypes,name='dtypes')
df.head(2).append(dtypes)
# Out:
#            10k                name division     25k  gender    age official  \
# 0        17.37  Yamamoto, Hiroyuki        8   47.67       M     47    85.25
# 1        32.58        Jeptoo, Rita        1   82.43       F     33   138.95
# dtypes  object              object    int64  object  object  int64  float64
#
#            bib genderdiv     ctz     35k overall     pace   state     30k  \
# 0           W1         8     NaN   71.40       8     3.27     NaN   59.18
# 1           F1         1     NaN  116.37      21      5.3     NaN   99.33
# dtypes  object     int64  object  object   int64  float64  object  object
#
#             5k    half     20k country     city     40k
# 0         8.02   39.72   37.65     JPN  Fukuoka   80.43
# 1        16.22   69.47   65.83     KEN  Eldoret  132.10
# dtypes  object  object  object  object   object  object

# %%
df['type']=0
df.loc[df.bib.str.contains('W'), 'type'] = 1
df.loc[df.bib.str.contains('F'), 'type'] = 2

# %%
df.type.value_counts()
# Out:
# 0    31883
# 1       53
# 2       48
# Name: type, dtype: int64

# %% [markdown]
# # 1. Data cleaning

# %% [markdown]
# We convert Gender to number using label encoder with Female is 0 and Male is 1.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df.gender = le.fit_transform(df.gender)

# show label and encoded values
for i, classes in enumerate(le.classes_):
    print("Label:",classes + ", Encoded value:",i )
# Out:
# Label: F, Encoded value: 0
# Label: M, Encoded value: 1

# %% [markdown]
# We drop rows where distance is not numeric-convertable then  apply the convertion and delete categorical columns.

# %%
# drop rows where distance is '-'
df.drop(df[df['10k']=='-'].index, axis=0, inplace=True)
df.drop(df[df['25k']=='-'].index, axis=0, inplace=True)
df.drop(df[df['35k']=='-'].index, axis=0, inplace=True)
df.drop(df[df['30k']=='-'].index, axis=0, inplace=True)
df.drop(df[df['half']=='-'].index, axis=0, inplace=True)
df.drop(df[df['20k']=='-'].index, axis=0, inplace=True)
df.drop(df[df['40k']=='-'].index, axis=0, inplace=True)
df.drop(df[df['5k']=='-'].index, axis=0, inplace=True)

# Convert to numeric
df['10k']=pd.to_numeric(df['10k'])
df['25k']=pd.to_numeric(df['25k'])
df['35k']=pd.to_numeric(df['35k'])
df['30k']=pd.to_numeric(df['30k'])
df['half']=pd.to_numeric(df['half'])
df['20k']=pd.to_numeric(df['20k'])
df['40k']=pd.to_numeric(df['40k'])
df['5k']=pd.to_numeric(df['5k'])

# clean outlier
df.drop(df[df['40k']>400].index, axis=0, inplace=True)

#rearrange column order
df=df[['gender','age','type','division','genderdiv','overall','pace','5k','10k','20k','half','25k','30k','35k','40k','official']]

# %% [markdown]
# <center>Table: Processed database

# %%
dtypes = pd.Series(df.dtypes,name='dtypes')
df.head(2).append(dtypes)
# Out:
#        gender    age   type division genderdiv overall     pace       5k  \
# 0           1     47      1        8         8       8     3.27     8.02
# 1           0     33      2        1         1      21      5.3    16.22
# dtypes  int64  int64  int64    int64     int64   int64  float64  float64
#
#             10k      20k     half      25k      30k      35k      40k official
# 0         17.37    37.65    39.72    47.67    59.18     71.4    80.43    85.25
# 1         32.58    65.83    69.47    82.43    99.33   116.37    132.1   138.95
# dtypes  float64  float64  float64  float64  float64  float64  float64  float64

# %% [markdown]
# # 2. Descriptive Statistics

# %% [markdown]
# We plot the line of all the milestones with the average speed from candidates.

# %%
a = df.loc[:,'5k':'official'].mean()
plt.plot(a, 'r',linewidth=3)
plt.plot(a, 'ks',linewidth=3)
plt.xlabel('Range')
plt.ylabel('Average (min)')
plt.annotate('15k is missing', xy=('20k', 107), xytext=('5k', 150),
             arrowprops=dict(facecolor='black', shrink=0.05))
plt.title('Range plotting')
plt.show()

# %% [markdown]
# The line can't visualize the speed correctly (the more steep the line is, the faster the average speed of candidates reach) as the milestones are not equally spaced. So we will directly calculate and plot the speed of them.

# %%
cspeed = [5,10,20,25,30,35,40]/df.loc[:,['5k','10k','20k','25k','30k','35k','40k']].mean()*1000/60

rdis = df.loc[:,['5k','10k','20k','25k','30k','35k','40k']].mean()
# shift range distance
rs = rdis.shift(1)
rs.loc['5k']=0
rspeed = [5,5,10,5,5,5,5]/(rdis-rs)*1000/60
pd.DataFrame([cspeed,rspeed],index=['cummulative speed','range speed'])
# Out:
#                          5k       10k       20k       25k       30k       35k  \
# cummulative speed  3.245287  3.228157  3.164915  3.119202  3.050736  2.975684
# range speed        3.245287  3.211207  3.104104  2.948832  2.749031  2.592945
#
#                         40k
# cummulative speed  2.921542
# range speed        2.591483

# %%
plt.figure(1, figsize=(10,4))
plt.subplot(121)
cspeed.plot.bar()
plt.xlabel('Range')
plt.ylabel('speed (m/s)')
plt.title('Cumulative speed plot')

plt.subplot(122)
rspeed.plot.bar()
plt.xlabel('Range')
plt.ylabel('speed (m/s)')
plt.title('Speed in each range plot')

plt.show()

# %% [markdown]
# The right plot explains the speed in each range more precisely. It not only shows how the speed decrease but also the stability of speed in the last 10km to the finish line.

# %% [markdown]
# <center>Figure: Correlation Matrix of some columns</center>

# %%
plt.figure(figsize=(10,8))
corr = df.loc[:,:].corr().round(2)
# mask = np.zeros_like(corr)
# mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr, cmap="seismic", square=True,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
            center=0, annot= True)
plt.xticks(rotation=45)
plt.show()

# %%
sns.pairplot(df, diag_kind="kde")
plt.show()

# %% [markdown]
# Relationship of 40k, age, genderdiv => not having special pattern to analyze

# %%
plt.scatter(df['40k'], df['age'],c=df['genderdiv'])
plt.xlabel('40k')
plt.ylabel('age')
plt.title("color = genderdiv")
plt.show()

# %% [markdown]
# To check 40k and genderdiv relalationship, we use hexagon density plot like below, the darker means that area place more values of 40k-genderdiv pair

# %%
df.plot.hexbin(x='40k',y='genderdiv',gridsize=20)
plt.ylabel('genderdiv')
plt.show()

# %% [markdown]
# Now we use normal black plot to show the pattern and then check if this pattern has any relationship with gender:

# %%
plt.figure(1,figsize=(12,4))

plt.subplot(121)
plt.scatter(df.loc[:,'40k'], df.loc[:,'genderdiv'], c='k')

plt.xlabel('40k')
plt.ylabel('genderdiv')
plt.title("40k - genderdiv")

plt.subplot(122)
plt.scatter(df.loc[df.gender==0,'40k'], df.loc[df.gender==0,'genderdiv'], c='r', label = 'female')
plt.scatter(df.loc[df.gender==1,'40k'], df.loc[df.gender==1,'genderdiv'], c='b', label = 'male')
plt.xlabel('40k')
plt.ylabel('genderdiv')
plt.title("40k - genderdiv classified by gender")
plt.legend(loc=2)
plt.show()

# %% [markdown]
# The plot shows there is a obvious relationship between 40k, gender and genderdiv.
# Now we start to use Kmean model to see if it can split the data into 2 group as well as above

# %% [markdown]
# # 3. Clustering

# %%
X = pd.DataFrame(df['40k'])

# %%
# prepare X to cluster
X.head(5)
# Out:
#       40k
# 0   80.43
# 1  132.10
# 2   76.10
# 3  132.95
# 4   76.72

# %% [markdown]
# ## 3.1. Kmeans

# %% [markdown]
# ### 3.1.1. Silhouette score

# %%
from sklearn.cluster import KMeans
kmean = KMeans(n_clusters=8, #int
                tol=0.0001, #float
                n_init=10) #int
# y_pred = kmean.fit_predict(X)

# %%
from sklearn.model_selection import RandomizedSearchCV

# Create a parameter grid: map the parameter names to the
# values that should be searched:
param_grid = dict(
    n_clusters=[2],
    tol=np.linspace(0.0001,100,10),
    n_init=[10,100,250,1000],
    algorithm=['auto','full','elkan'],
)

from sklearn.metrics import silhouette_score
def silhouette(estimator, X):
    clusters = estimator.fit_predict(X)
    score = silhouette_score(X, clusters)
    return score

# Instantiate the grid:
grid = RandomizedSearchCV(kmean, param_grid, cv=5, error_score=0.0,
                          scoring=silhouette, n_jobs=1, n_iter=10)

# fit the grid with data
grid.fit(X)

# examine the best model
print(grid.best_score_)
print(grid.best_params_)

# gre = Gridsearchcv REsult
gre = pd.DataFrame(grid.cv_results_)
(gre.loc[gre.mean_test_score!=0] # skip zero scored rows
     [['rank_test_score','mean_fit_time','mean_test_score'] # get these col
          +['param_{}'.format(i) for i in grid.best_params_.keys()]]
    .sort_values('rank_test_score')) # sort by rank
# Out:
# 0.6135140168717962
# {'tol': 77.77780000000001, 'n_init': 10, 'n_clusters': 2, 'algorithm': 'full'}
#    rank_test_score  mean_fit_time  mean_test_score param_tol param_n_init  \
# 1                1       0.194756         0.613514   77.7778           10
# 9                2       0.192061         0.610423   33.3334           10
# 7                3       0.063488         0.610309   44.4445           10
# 4                4       1.489322         0.606321   77.7778          250
# 6                5      66.373993         0.606030    0.0001         1000
# 5                6       0.593552         0.605789   44.4445          100
# 3                7       0.063388         0.605567       100           10
# 2                8       0.197351         0.603699   66.6667           10
# 8                9       0.186870         0.603294       100           10
# 0               10       0.087945         0.602644   88.8889           10
#
#   param_n_clusters param_algorithm
# 1                2            full
# 9                2            full
# 7                2           elkan
# 4                2           elkan
# 6                2            full
# 5                2           elkan
# 3                2           elkan
# 2                2            full
# 8                2            full
# 0                2           elkan

# %%
from sklearn.cluster import KMeans
kmean = KMeans(n_clusters=2,
                tol= 77.7777,
                n_init=10,
                algorithm='full',
                n_jobs=16)
y_pred = kmean.fit_predict(X)

# %%
plt.scatter(X['40k'], X['40k'].index, c=y_pred)
plt.xlabel('40k')
plt.title("40k - genderdiv classified using kmeans")
plt.show()

# %% [markdown]
# ### 3.1.2. (test) calinski harabaz

# %%
from sklearn.model_selection import RandomizedSearchCV

# Create a parameter grid: map the parameter names to the
# values that should be searched:
param_grid = dict(
    n_clusters=[2],
    tol=np.linspace(0.0001,100,10),
    n_init=[10,100,250,1000],
    algorithm=['auto','full','elkan'],
)

from sklearn.metrics import calinski_harabaz_score
def calinski(estimator, X):
    clusters = estimator.fit_predict(X)
    score = calinski_harabaz_score(X, clusters)
    return score

# Instantiate the grid:
grid = RandomizedSearchCV(kmean, param_grid, cv=5, error_score=0.0,
                          scoring=calinski, n_jobs=1, n_iter=10)

# fit the grid with data
grid.fit(X)

# examine the best model
print(grid.best_score_)
print(grid.best_params_)

# gre = Gridsearchcv REsult
gre = pd.DataFrame(grid.cv_results_)
(gre.loc[gre.mean_test_score!=0] # skip zero scored rows
     [['rank_test_score','mean_fit_time','mean_test_score'] # get these col
          +['param_{}'.format(i) for i in grid.best_params_.keys()]]
    .sort_values('rank_test_score')) # sort by rank
# Out:
# 9872.364915594115
# {'tol': 88.8889, 'n_init': 1000, 'n_clusters': 2, 'algorithm': 'auto'}
#    rank_test_score  mean_fit_time  mean_test_score param_tol param_n_init  \
# 4                1       5.615762      9872.364916   88.8889         1000
# 6                2       5.603009      9872.362366   11.1112         1000
# 9                3       0.567897      9872.316738   44.4445          100
# 1                4       4.227543      9872.302742   22.2223          250
# 5                5       0.564703      9872.210126   66.6667          100
# 8                6       0.567199      9872.193516   66.6667          100
# 0                7       0.164258      9872.162832    0.0001           10
# 7                8       1.697443      9871.846489   22.2223          100
# 2                9       1.689018      9870.859467   88.8889          100
# 3               10       0.059096      9841.774017       100           10
#
#   param_n_clusters param_algorithm
# 4                2            auto
# 6                2           elkan
# 9                2           elkan
# 1                2            full
# 5                2           elkan
# 8                2            auto
# 0                2           elkan
# 7                2            full
# 2                2            full
# 3                2           elkan

# %%
from sklearn.cluster import KMeans
kmean = KMeans(n_clusters=2,
                tol= 88.8889,
                n_init=1000,
                algorithm='auto',
                n_jobs=16)
y_pred = kmean.fit_predict(X)

# %%
plt.scatter(X['40k'], X['40k'].index, c=y_pred)
plt.xlabel('40k')
plt.title("40k classified using kmeans")
plt.show()

# %% [markdown]
# ## 3.2. DBSCAN

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=10, #float
                min_samples=50, #int
                metric='euclidean', # 'cosine','manhattan',
                algorithm='auto') # 'ball_tree','kd_tree','brute'
y_pred = dbscan.fit_predict(X)

# %%
plt.scatter(X['40k'], X['40k'].index, c=y_pred, alpha=0.5)
plt.xlabel('40k')
plt.title("40k classified using DBSCAN")
plt.show()

# %% [markdown]
# ### 3.2.1. Silhouette score

# %%
from sklearn.metrics import silhouette_score
silhouette_score(X, y_pred)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-36-551a86e5cd07> in <module>()
#       1 from sklearn.metrics import silhouette_score
# ----> 2 silhouette_score(X, y_pred)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\cluster\unsupervised.py in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#      99         else:
#     100             X, labels = X[indices], labels[indices]
# --> 101     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#     102
#     103
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\cluster\unsupervised.py in silhouette_samples(X, labels, metric, **kwds)
#     190         if n_samples_curr_lab != 0:
#     191             intra_clust_dists[mask] = np.sum(
# --> 192                 current_distances[:, mask], axis=1) / n_samples_curr_lab
#     193
#     194         # Now iterate over all other labels, finding the mean
#
# MemoryError:

# %% [markdown]
# ### 3.2.2. (test) Calinski - Harabaz score

# %%
from sklearn.metrics import calinski_harabaz_score
calinski_harabaz_score(X, y_pred)
# Out:
# 367.220352567288

# %% [markdown]
# # 4. Discover the pattern of clustered item

# %% [markdown]
# We plot the pattern of 40k using some features:

# %%
plt.figure(1,figsize=(10,7))

plt.subplot(221)
plt.scatter(df['40k'], df.index, c=df['type'].values, alpha=0.5)
plt.title("40k classified by type")

plt.subplot(222)
plt.scatter(df['40k'], df.index, c=df['gender'].values, alpha=0.5)
plt.title("40k classified by gender")

plt.subplot(223)
plt.scatter(df['40k'], df.index, c=df['age'].values, alpha=0.7)
plt.xlabel('40k')
plt.title("40k classified by age")

plt.subplot(224)
plt.scatter(df['40k'], df.index, c=df['genderdiv'].values, alpha=0.7)
plt.xlabel('40k')
plt.title("40k classified by genderdiv")
plt.show()

# %% [markdown]
# # 5. Conclusion
# The DBSCAN model is better to cluster 40k in this database but the validation methods are not suitable in this case
